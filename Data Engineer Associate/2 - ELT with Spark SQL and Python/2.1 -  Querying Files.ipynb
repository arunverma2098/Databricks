# %%
# %sql
USE CATALOG workspace;

# %%
# %sql
USE SCHEMA bookstore_eng_ass;

# %%
dbutils.fs.ls("/Volumes/workspace/bookstore_eng_ass/dataset/customers-json/")

# %%
# %sql
select * from json.`/Volumes/workspace/bookstore_eng_ass/dataset/customers-json/*.json`

# %%
# %sql
select * from text.`/Volumes/workspace/bookstore_eng_ass/dataset/customers-json/`

# %%
# %sql
select * from binaryFile.`/Volumes/workspace/bookstore_eng_ass/dataset/customers-json/`

# %%
# %sql
select * from csv.`/Volumes/workspace/bookstore_eng_ass/dataset/books-csv/`

# %%
# %sql
create table books as 
select * from read_files(
  "/Volumes/workspace/bookstore_eng_ass/dataset/books-csv/export_*.csv",
  format => 'csv',
  header => 'true',
  delimiter => ";"
);

# %%
# %sql
create table customers as
select * from read_files(
  "/Volumes/workspace/bookstore_eng_ass/dataset/customers-json/export_*.json",
  format => 'json'
)
